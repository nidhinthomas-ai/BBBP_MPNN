# %%
# !pip install rdkit-pypi
# !pip install pandas
# !pip install Pillow
# !pip install matplotlib
# !pip install pydot
# !sudo apt-get -qq install graphviz
# Out:
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 40.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (1.25.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (9.4.0)
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pydot in /usr/local/lib/python3.10/dist-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from pydot) (3.1.1)

# %%
# !python train.py --dataset data/BBBP.csv
# Out:
# 2024-02-29 07:53:27.532819: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-29 07:53:27.532874: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-29 07:53:27.534232: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-29 07:53:27.541555: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-29 07:53:28.616028: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-02-29 07:53:33.041969: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-29 07:53:33.626853: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-29 07:53:33.627170: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-29 07:53:33.628239: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-29 07:53:33.628541: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-29 07:53:33.628856: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-29 07:53:33.812969: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-29 07:53:33.813306: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-29 07:53:33.813447: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-02-29 07:53:33.813559: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-29 07:53:33.813729: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14792 MB memory:  -> device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0
# Epoch 1/40
# 2024-02-29 07:53:45.669566: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# 2024-02-29 07:53:47.835386: I external/local_xla/xla/service/service.cc:168] XLA service 0x785c896fbf20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-02-29 07:53:47.835445: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-16GB, Compute Capability 7.0
# 2024-02-29 07:53:47.858074: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1709193228.037967    7099 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#
# Epoch 1: val_loss improved from inf to 0.55141, saving model to ./mpnn_best_model.h5
# 52/52 - 13s - loss: 0.5494 - AUC: 0.6770 - val_loss: 0.5514 - val_AUC: 0.8316 - 13s/epoch - 256ms/step
# Epoch 2/40
#
# Epoch 2: val_loss did not improve from 0.55141
# 52/52 - 1s - loss: 0.4744 - AUC: 0.7858 - val_loss: 0.5770 - val_AUC: 0.8479 - 922ms/epoch - 18ms/step
# Epoch 3/40
#
# Epoch 3: val_loss did not improve from 0.55141
# 52/52 - 1s - loss: 0.4570 - AUC: 0.8032 - val_loss: 0.6372 - val_AUC: 0.8517 - 980ms/epoch - 19ms/step
# Epoch 4/40
#
# Epoch 4: val_loss improved from 0.55141 to 0.50357, saving model to ./mpnn_best_model.h5
# 52/52 - 1s - loss: 0.4478 - AUC: 0.8092 - val_loss: 0.5036 - val_AUC: 0.8611 - 1s/epoch - 21ms/step
# Epoch 5/40
#
# Epoch 5: val_loss did not improve from 0.50357
# 52/52 - 1s - loss: 0.4356 - AUC: 0.8227 - val_loss: 0.5397 - val_AUC: 0.8640 - 1s/epoch - 20ms/step
# Epoch 6/40
#
# Epoch 6: val_loss improved from 0.50357 to 0.49273, saving model to ./mpnn_best_model.h5
# 52/52 - 1s - loss: 0.4316 - AUC: 0.8281 - val_loss: 0.4927 - val_AUC: 0.8649 - 1s/epoch - 20ms/step
# Epoch 7/40
#
# Epoch 7: val_loss did not improve from 0.49273
# 52/52 - 2s - loss: 0.4191 - AUC: 0.8386 - val_loss: 0.5291 - val_AUC: 0.8669 - 2s/epoch - 35ms/step
# Epoch 8/40
#
# Epoch 8: val_loss did not improve from 0.49273
# 52/52 - 1s - loss: 0.4136 - AUC: 0.8462 - val_loss: 0.5546 - val_AUC: 0.8667 - 1s/epoch - 25ms/step
# Epoch 9/40
#
# Epoch 9: val_loss did not improve from 0.49273
# 52/52 - 1s - loss: 0.4165 - AUC: 0.8421 - val_loss: 0.5877 - val_AUC: 0.8686 - 1s/epoch - 21ms/step
# Epoch 10/40
#
# Epoch 10: val_loss did not improve from 0.49273
# 52/52 - 1s - loss: 0.4124 - AUC: 0.8473 - val_loss: 0.6242 - val_AUC: 0.8674 - 1s/epoch - 19ms/step
# Epoch 11/40
#
# Epoch 11: val_loss did not improve from 0.49273
# 52/52 - 1s - loss: 0.4136 - AUC: 0.8433 - val_loss: 0.6293 - val_AUC: 0.8722 - 941ms/epoch - 18ms/step
# Epoch 12/40
#
# Epoch 12: val_loss did not improve from 0.49273
# 52/52 - 1s - loss: 0.3946 - AUC: 0.8611 - val_loss: 0.5765 - val_AUC: 0.8734 - 1s/epoch - 20ms/step
# Epoch 13/40
#
# Epoch 13: val_loss did not improve from 0.49273
# 52/52 - 1s - loss: 0.3810 - AUC: 0.8708 - val_loss: 0.5792 - val_AUC: 0.8822 - 1s/epoch - 19ms/step
# Epoch 14/40
#
# Epoch 14: val_loss did not improve from 0.49273
# 52/52 - 1s - loss: 0.3684 - AUC: 0.8820 - val_loss: 0.5489 - val_AUC: 0.8978 - 1s/epoch - 20ms/step
# Epoch 15/40
#
# Epoch 15: val_loss did not improve from 0.49273
# 52/52 - 1s - loss: 0.3685 - AUC: 0.8808 - val_loss: 0.5179 - val_AUC: 0.8864 - 1s/epoch - 19ms/step
# Epoch 16/40
#
# Epoch 16: val_loss did not improve from 0.49273
# 52/52 - 1s - loss: 0.3538 - AUC: 0.8923 - val_loss: 0.6149 - val_AUC: 0.9007 - 1s/epoch - 27ms/step
# Epoch 17/40
#
# Epoch 17: val_loss did not improve from 0.49273
# 52/52 - 2s - loss: 0.3517 - AUC: 0.8925 - val_loss: 0.5054 - val_AUC: 0.8997 - 2s/epoch - 30ms/step
# Epoch 18/40
#
# Epoch 18: val_loss improved from 0.49273 to 0.46903, saving model to ./mpnn_best_model.h5
# 52/52 - 1s - loss: 0.3375 - AUC: 0.9009 - val_loss: 0.4690 - val_AUC: 0.8944 - 1s/epoch - 22ms/step
# Epoch 19/40
#
# Epoch 19: val_loss did not improve from 0.46903
# 52/52 - 1s - loss: 0.3412 - AUC: 0.8992 - val_loss: 0.4728 - val_AUC: 0.8956 - 1s/epoch - 21ms/step
# Epoch 20/40
#
# Epoch 20: val_loss improved from 0.46903 to 0.45150, saving model to ./mpnn_best_model.h5
# 52/52 - 1s - loss: 0.3285 - AUC: 0.9075 - val_loss: 0.4515 - val_AUC: 0.8936 - 1s/epoch - 19ms/step
# Epoch 21/40
#
# Epoch 21: val_loss did not improve from 0.45150
# 52/52 - 1s - loss: 0.3214 - AUC: 0.9120 - val_loss: 0.4883 - val_AUC: 0.8986 - 997ms/epoch - 19ms/step
# Epoch 22/40
#
# Epoch 22: val_loss did not improve from 0.45150
# 52/52 - 1s - loss: 0.3182 - AUC: 0.9140 - val_loss: 0.4667 - val_AUC: 0.8953 - 951ms/epoch - 18ms/step
# Epoch 23/40
#
# Epoch 23: val_loss improved from 0.45150 to 0.42988, saving model to ./mpnn_best_model.h5
# 52/52 - 1s - loss: 0.3096 - AUC: 0.9190 - val_loss: 0.4299 - val_AUC: 0.8863 - 1s/epoch - 21ms/step
# Epoch 24/40
#
# Epoch 24: val_loss did not improve from 0.42988
# 52/52 - 1s - loss: 0.3165 - AUC: 0.9149 - val_loss: 0.4466 - val_AUC: 0.8906 - 1s/epoch - 19ms/step
# Epoch 25/40
#
# Epoch 25: val_loss improved from 0.42988 to 0.41825, saving model to ./mpnn_best_model.h5
# 52/52 - 1s - loss: 0.2939 - AUC: 0.9279 - val_loss: 0.4182 - val_AUC: 0.8857 - 1s/epoch - 23ms/step
# Epoch 26/40
#
# Epoch 26: val_loss did not improve from 0.41825
# 52/52 - 2s - loss: 0.2955 - AUC: 0.9265 - val_loss: 0.4576 - val_AUC: 0.8784 - 2s/epoch - 30ms/step
# Epoch 27/40
#
# Epoch 27: val_loss did not improve from 0.41825
# 52/52 - 1s - loss: 0.2768 - AUC: 0.9354 - val_loss: 0.4230 - val_AUC: 0.8864 - 1s/epoch - 25ms/step
# Epoch 28/40
#
# Epoch 28: val_loss did not improve from 0.41825
# 52/52 - 1s - loss: 0.2916 - AUC: 0.9284 - val_loss: 0.4349 - val_AUC: 0.8771 - 1s/epoch - 21ms/step
# Epoch 29/40
#
# Epoch 29: val_loss improved from 0.41825 to 0.40737, saving model to ./mpnn_best_model.h5
# 52/52 - 1s - loss: 0.2822 - AUC: 0.9331 - val_loss: 0.4074 - val_AUC: 0.8852 - 1s/epoch - 21ms/step
# Epoch 30/40
#
# Epoch 30: val_loss did not improve from 0.40737
# 52/52 - 1s - loss: 0.2676 - AUC: 0.9392 - val_loss: 0.4851 - val_AUC: 0.8787 - 985ms/epoch - 19ms/step
# Epoch 31/40
#
# Epoch 31: val_loss did not improve from 0.40737
# 52/52 - 1s - loss: 0.2716 - AUC: 0.9371 - val_loss: 0.4088 - val_AUC: 0.8925 - 1s/epoch - 20ms/step
# Epoch 32/40
#
# Epoch 32: val_loss did not improve from 0.40737
# 52/52 - 1s - loss: 0.2661 - AUC: 0.9410 - val_loss: 0.4251 - val_AUC: 0.8981 - 995ms/epoch - 19ms/step
# Epoch 33/40
#
# Epoch 33: val_loss did not improve from 0.40737
# 52/52 - 1s - loss: 0.2385 - AUC: 0.9519 - val_loss: 0.4642 - val_AUC: 0.8958 - 1s/epoch - 19ms/step
# Epoch 34/40
#
# Epoch 34: val_loss did not improve from 0.40737
# 52/52 - 1s - loss: 0.2360 - AUC: 0.9524 - val_loss: 0.4614 - val_AUC: 0.8870 - 1s/epoch - 19ms/step
# Epoch 35/40
#
# Epoch 35: val_loss did not improve from 0.40737
# 52/52 - 1s - loss: 0.2611 - AUC: 0.9418 - val_loss: 0.5109 - val_AUC: 0.8886 - 991ms/epoch - 19ms/step
# Epoch 36/40
#
# Epoch 36: val_loss did not improve from 0.40737
# 52/52 - 2s - loss: 0.2458 - AUC: 0.9480 - val_loss: 0.4693 - val_AUC: 0.8894 - 2s/epoch - 32ms/step
# Epoch 37/40
#
# Epoch 37: val_loss did not improve from 0.40737
# 52/52 - 1s - loss: 0.2365 - AUC: 0.9510 - val_loss: 0.4567 - val_AUC: 0.9039 - 1s/epoch - 27ms/step
# Epoch 38/40
#
# Epoch 38: val_loss did not improve from 0.40737
# 52/52 - 1s - loss: 0.2228 - AUC: 0.9561 - val_loss: 0.4621 - val_AUC: 0.8962 - 1s/epoch - 20ms/step
# Epoch 39/40
#
# Epoch 39: val_loss did not improve from 0.40737
# 52/52 - 1s - loss: 0.2252 - AUC: 0.9551 - val_loss: 0.4473 - val_AUC: 0.8922 - 1s/epoch - 20ms/step
# Epoch 40/40
#
# Epoch 40: val_loss did not improve from 0.40737
# 52/52 - 1s - loss: 0.2428 - AUC: 0.9491 - val_loss: 0.4443 - val_AUC: 0.9020 - 966ms/epoch - 19ms/step
# Figure(1000x600)

# %%
# !mkdir ./drive/MyDrive/BBBP_MPNN
# !cp mpnn_best_model.h5 ./drive/MyDrive/BBBP_MPNN/

# %%
# !python inference.py --dataset ./data/BBBP.csv --model_path ./mpnn_best_model.h5  --output_path ./bbbp_mpnn_pred
# Out:
# 1/1 [==============================] - 2s 2s/step
